# %% [markdown]
# # 03 Stock Pitch Case Study
#
# This notebook uses the manual AAPL sample input to generate a report-style reverse DCF case study. It is educational only and not an investment recommendation.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))
sys.path.insert(0, str(ROOT / "src"))

from scripts.generate_report import build_report

# %%
report_path = build_report(
    input_path=ROOT / "data/sample_inputs/aapl.json",
    output_path=ROOT / "reports/sample_report.md",
    revenue_cagr=0.08,
    wacc=0.08,
    terminal_growth=0.025,
    forecast_years=5,
)
report_path

# %% [markdown]
# Review the generated markdown report and figures under `reports/`.
